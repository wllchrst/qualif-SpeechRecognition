# %%
# importing all the library 
import os
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display
# Out:
# c:\ProgramData\anaconda3\envs\speech_recognition\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Defining the File Directory
DATASET_PATH = "./speech_commands/"
DATA_DIR = pathlib.Path(DATASET_PATH)

# %%
# getting the dataset from out file directory
train_dataset, validation_dataset = tf.keras.utils.audio_dataset_from_directory(
    directory=DATA_DIR,
    batch_size=64,
    validation_split=0.2,
    seed = 0,
    output_sequence_length=16000,
    subset="both"
)

print(train_dataset)
# Out:
# Found 16471 files belonging to 7 classes.
# Using 13177 files for training.
# Using 3294 files for validation.
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 16000, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# defining the label names
LABEL_NAMES = np.array(train_dataset.class_names)
print(LABEL_NAMES)
# Out:
# ['down' 'left' 'off' 'on' 'right' 'stop' 'up']

# %%
# as we can that the size of shape of the audio array has one useless dimension 
for audio, labels in train_dataset.take(1) : 
    print(audio.shape)
    for label in labels :
        print(label) 

# ! data definition
# * audio = the audio file represented in numbers
# * labels = number of the index in the LABEL_NAMES
# Out:
# (64, 16000, 1)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)

# %%
# ! so we are going to squeeze the array
def squeeze_array(audio, label) : 
    audio = tf.squeeze(audio, axis=-1) # we are going to delete the last dimension of the array
    print()
    print()
    return audio, label

train_dataset = train_dataset.map(squeeze_array, tf.data.AUTOTUNE)
validation_dataset = validation_dataset.map(squeeze_array, tf.data.AUTOTUNE)

print(train_dataset)
# Out:
# <_ParallelMapDataset element_spec=(TensorSpec(shape=(None, 16000), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# The array has been squeezed
for audio, labels in train_dataset.take(1) :
    print(audio.shape)
# Out:
# (64, 16000)

# %%
## creating the test dataset

test_dataset = validation_dataset.shard(num_shards=2, index=0)
validation_dataset = validation_dataset.shard(num_shards=2, index=1)

# %% [markdown]
# > Now that our dataset has been preprocessed and split into train, validation, test data set. We are going to turn it to spectrogram.

# %%
# function for turning the audio data set into spectrogram
def get_spectrogram(audio) : # turning the audio dataset into a spectrogram.
    spectrogram = tf.signal.stft(audio, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)
    spectrogram = spectrogram[..., tf.newaxis]
    print(spectrogram.shape)
    return spectrogram

def transform_dataset_into_spectrogram (dataset): 
    return dataset.map(map_func = lambda audio, label : (get_spectrogram(audio), label), 
                       num_parallel_calls = tf.data.AUTOTUNE)

# %%
# Using the function above to turn the dataset into spectrogram.
train_dataset_spec = transform_dataset_into_spectrogram(train_dataset)
test_dataset_spec = transform_dataset_into_spectrogram(test_dataset)
validation_dataset_spec = transform_dataset_into_spectrogram(validation_dataset)

print(train_dataset_spec)

# Next we are going to cache the dataset into our memory making the process more faster.
train_dataset_spec = train_dataset_spec.cache().shuffle(10000).prefetch(tf.data.AUTOTUNE)
train_dataset_spec = train_dataset_spec.cache().prefetch(tf.data.AUTOTUNE)
validation_dataset_spec = validation_dataset_spec.cache().prefetch(tf.data.AUTOTUNE)
# Out:
# (None, 124, 129, 1)
# (None, 124, 129, 1)
# (None, 124, 129, 1)
# <_ParallelMapDataset element_spec=(TensorSpec(shape=(None, 124, 129, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# > We are going to do preparation for making our model

# %%
for SAMPLE_SPECTROGRAM, SAMPLE_LABELS in train_dataset_spec :
    print(SAMPLE_SPECTROGRAM)
    break
# Out:
# tf.Tensor(
# [[[[3.31344232e-02]
#    [5.03309630e-02]
#    [5.34809232e-02]
#    ...
#    [3.53633630e-04]
#    [3.47502792e-04]
#    [1.99779868e-04]]
#
#   [[3.65861766e-02]
#    [1.74628887e-02]
#    [3.47451381e-02]
#    ...
#    [1.22331970e-04]
#    [1.51530476e-04]
#    [4.82164323e-05]]
#
#   [[3.08959633e-02]
#    [3.43851745e-02]
#    [6.44320548e-02]
#    ...
#    [2.55096791e-04]
#    [4.09472595e-05]
#    [1.84332021e-04]]
#
#   ...
#
#   [[1.65800428e+00]
#    [3.36848831e+00]
#    [2.68951297e+00]
#    ...
#    [2.00758368e-04]
#    [3.37230304e-04]
#    [3.24428082e-04]]
#
#   [[2.18381858e+00]
#    [2.50447154e+00]
#    [3.50471091e+00]
#    ...
#    [5.31728438e-04]
#    [3.98737466e-04]
#    [7.84397125e-05]]
#
#   [[1.10471213e+00]
#    [1.94156039e+00]
#    [3.59231162e+00]
#    ...
#    [4.21403674e-04]
#    [4.04695136e-04]
#    [1.96337700e-04]]]
#
#
#  [[[6.38546228e-01]
#    [3.39604288e-01]
#    [1.65407043e-02]
#    ...
#    [5.58451065e-05]
#    [7.68117898e-05]
#    [1.25795603e-04]]
#
#   [[9.61357474e-01]
#    [5.03650844e-01]
#    [4.59427610e-02]
#    ...
#    [9.92627465e-05]
#    [9.50082831e-05]
#    [1.25169754e-05]]
#
#   [[1.20970297e+00]
#    [6.80798769e-01]
#    [1.06008567e-01]
#    ...
#    [5.67512325e-05]
#    [2.72337184e-05]
#    [3.24249268e-05]]
#
#   ...
#
#   [[4.82119739e-01]
#    [4.00620461e-01]
#    [1.94374010e-01]
#    ...
#    [1.91669344e-04]
#    [1.32979476e-04]
#    [2.09957361e-05]]
#
#   [[3.25540572e-01]
#    [2.08870932e-01]
#    [1.08523697e-01]
#    ...
#    [1.28036714e-04]
#    [1.55173504e-04]
#    [1.93387270e-04]]
#
#   [[3.91359955e-01]
#    [2.48538539e-01]
#    [1.23187996e-01]
#    ...
#    [4.83970653e-05]
#    [1.98058187e-05]
#    [7.62641430e-05]]]
#
#
#  [[[1.65569372e-02]
#    [1.84040200e-02]
#    [8.04699957e-03]
#    ...
#    [3.12594115e-04]
#    [4.97404872e-05]
#    [4.14941460e-05]]
#
#   [[2.69448534e-02]
#    [2.10837964e-02]
#    [8.26958381e-03]
#    ...
#    [1.85776153e-04]
#    [1.40202479e-04]
#    [2.99112871e-05]]
#
#   [[4.60675173e-03]
#    [4.66931699e-04]
#    [1.43602199e-03]
#    ...
#    [1.59647796e-04]
#    [7.19668315e-05]
#    [5.64772636e-05]]
#
#   ...
#
#   [[0.00000000e+00]
#    [0.00000000e+00]
#    [0.00000000e+00]
#    ...
#    [0.00000000e+00]
#    [0.00000000e+00]
#    [0.00000000e+00]]
#
#   [[0.00000000e+00]
#    [0.00000000e+00]
#    [0.00000000e+00]
#    ...
#    [0.00000000e+00]
#    [0.00000000e+00]
#    [0.00000000e+00]]
#
#   [[0.00000000e+00]
#    [0.00000000e+00]
#    [0.00000000e+00]
#    ...
#    [0.00000000e+00]
#    [0.00000000e+00]
#    [0.00000000e+00]]]
#
#
#  ...
#
#
#  [[[1.59550749e-04]
#    [7.93296378e-04]
#    [1.15266757e-03]
#    ...
#    [2.58025339e-05]
#    [9.03502441e-05]
#    [1.69538253e-04]]
#
#   [[1.84607378e-03]
#    [1.80166156e-03]
#    [2.20401655e-03]
#    ...
#    [1.38217220e-04]
#    [1.16603944e-04]
#    [1.26476516e-04]]
#
#   [[2.43131188e-04]
#    [2.18454376e-03]
#    [2.12371908e-03]
#    ...
#    [9.16762001e-05]
#    [7.87522295e-05]
#    [5.89437550e-05]]
#
#   ...
#
#   [[1.26261485e-03]
#    [9.78757394e-04]
#    [1.65163467e-04]
#    ...
#    [1.52483757e-04]
#    [1.28841712e-04]
#    [1.05191139e-04]]
#
#   [[7.44507764e-04]
#    [8.08407494e-04]
#    [2.91663513e-04]
#    ...
#    [6.52791205e-05]
#    [3.27393791e-05]
#    [3.12546035e-07]]
#
#   [[5.40125300e-04]
#    [7.81581388e-04]
#    [6.09126408e-04]
#    ...
#    [6.78740325e-05]
#    [5.12228871e-05]
#    [8.26327305e-05]]]
#
#
#  [[[2.13569812e-02]
#    [4.00631167e-02]
#    [1.78985354e-02]
#    ...
#    [3.29917566e-05]
#    [5.91587341e-05]
#    [5.26541844e-05]]
#
#   [[3.83473262e-02]
#    [7.35489056e-02]
#    [6.63561672e-02]
#    ...
#    [1.04611827e-04]
#    [1.14113536e-04]
#    [9.32198018e-05]]
#
#   [[8.59486870e-03]
#    [4.54157740e-02]
#    [1.69116184e-02]
#    ...
#    [9.93617214e-05]
#    [1.01917823e-04]
#    [3.37082893e-05]]
#
#   ...
#
#   [[4.47507575e-02]
#    [5.69960177e-02]
#    [4.35339138e-02]
#    ...
#    [8.97040009e-05]
#    [1.25302322e-04]
#    [1.87121332e-05]]
#
#   [[4.12856340e-02]
#    [4.44247313e-02]
#    [4.53509167e-02]
#    ...
#    [7.82518619e-05]
#    [5.22034825e-05]
#    [2.07666308e-05]]
#
#   [[2.19560452e-02]
#    [3.24231163e-02]
#    [4.51515242e-02]
#    ...
#    [1.20955003e-04]
#    [9.55634605e-05]
#    [5.25042415e-05]]]
#
#
#  [[[9.75871366e-03]
#    [5.44362096e-03]
#    [8.61235254e-04]
#    ...
#    [1.10966394e-04]
#    [6.70036752e-05]
#    [6.00544736e-05]]
#
#   [[7.69128557e-04]
#    [1.54550059e-03]
#    [5.17404987e-04]
#    ...
#    [6.71522721e-05]
#    [4.26226543e-05]
#    [3.72728391e-05]]
#
#   [[4.50606272e-03]
#    [4.05459618e-03]
#    [1.41065137e-03]
#    ...
#    [9.99001786e-05]
#    [1.11107867e-04]
#    [7.26729631e-05]]
#
#   ...
#
#   [[1.45100374e-02]
#    [1.02959849e-01]
#    [2.47257762e-02]
#    ...
#    [1.40884993e-04]
#    [2.96492090e-05]
#    [1.11941714e-04]]
#
#   [[2.38600478e-01]
#    [1.34821728e-01]
#    [1.21266348e-02]
#    ...
#    [2.36622691e-05]
#    [4.69940460e-05]
#    [8.75145197e-05]]
#
#   [[1.71780527e-01]
#    [9.61971134e-02]
#    [9.50465165e-03]
#    ...
#    [6.21588988e-05]
#    [8.06906974e-05]
#    [4.09707427e-05]]]], shape=(64, 124, 129, 1), dtype=float32)

# %%
INPUT_SHAPE = SAMPLE_SPECTROGRAM.shape[1:]
LABEL_AMOUNT = len(LABEL_NAMES)

## CREATING THE NORMALIZATION LAYER
NORMALIZATION_LAYER = layers.Normalization()
NORMALIZATION_LAYER.adapt(data = train_dataset_spec.map(map_func = lambda spec, label : spec))

MODEL = models.Sequential(
    [
        layers.Input(shape=INPUT_SHAPE),
        layers.Resizing(32,32),
        NORMALIZATION_LAYER,
        layers.Conv2D(32, 3, activation='relu'),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(LABEL_AMOUNT)
    ]
)

# %%
MODEL.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 32, 32, 1)         0
#
#  normalization (Normalizatio  (None, 32, 32, 1)        3
#  n)
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 128)               1605760
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 1,625,482
# Trainable params: 1,625,479
# Non-trainable params: 3
# _________________________________________________________________

# %%
MODEL.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
EPOCH = 20

MODEL_FIT = MODEL.fit(
    train_dataset_spec,
    validation_data = validation_dataset_spec,
    epochs = EPOCH,
    callbacks = tf.keras.callbacks.EarlyStopping(verbose = 1, patience = 2)
)
# Out:
# Epoch 1/20
# 206/206 [==============================] - 30s 141ms/step - loss: 1.2850 - accuracy: 0.5500 - val_loss: 0.6978 - val_accuracy: 0.7834
# Epoch 2/20
# 206/206 [==============================] - 28s 138ms/step - loss: 0.6556 - accuracy: 0.7855 - val_loss: 0.4362 - val_accuracy: 0.8638
# Epoch 3/20
# 206/206 [==============================] - 25s 124ms/step - loss: 0.4767 - accuracy: 0.8442 - val_loss: 0.3604 - val_accuracy: 0.8816
# Epoch 4/20
# 206/206 [==============================] - 25s 122ms/step - loss: 0.3782 - accuracy: 0.8730 - val_loss: 0.3202 - val_accuracy: 0.8945
# Epoch 5/20
# 206/206 [==============================] - 26s 128ms/step - loss: 0.3308 - accuracy: 0.8869 - val_loss: 0.2733 - val_accuracy: 0.9031
# Epoch 6/20
# 206/206 [==============================] - 26s 126ms/step - loss: 0.2703 - accuracy: 0.9114 - val_loss: 0.2674 - val_accuracy: 0.9123
# Epoch 7/20
# 206/206 [==============================] - 26s 125ms/step - loss: 0.2521 - accuracy: 0.9162 - val_loss: 0.2453 - val_accuracy: 0.9190
# Epoch 8/20
# 206/206 [==============================] - 26s 129ms/step - loss: 0.2225 - accuracy: 0.9269 - val_loss: 0.2558 - val_accuracy: 0.9172
# Epoch 9/20
# 206/206 [==============================] - 26s 124ms/step - loss: 0.2057 - accuracy: 0.9312 - val_loss: 0.2512 - val_accuracy: 0.9196
# Epoch 9: early stopping

# %%
metrics = MODEL_FIT.history
VALIDATION_ACCURACY= metrics["accuracy"]
print(f"Highest Accuracy of the model training : {np.max(np.array(VALIDATION_ACCURACY))}")
# Out:
# Highest Accuracy of the model training : 0.9312438368797302

# %%
## doing prediction with our test dataset
print(test_dataset_spec)
prediction = MODEL.predict(test_dataset_spec)
prediction = tf.argmax(prediction, axis=1)
# Out:
# <_ParallelMapDataset element_spec=(TensorSpec(shape=(None, 124, 129, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# 26/26 [==============================] - 2s 54ms/step

# %%
def convert_to_label(labels) : 
    return [LABEL_NAMES[label.numpy()] for label in labels]

prediction = convert_to_label(prediction)
true_prediction = convert_to_label(tf.concat([label for _, label in test_dataset_spec], axis=0))


for index, (true_label, pred_label) in enumerate(zip(true_prediction, prediction)) :
    print(f"Data {index} : Original Label {true_label}, Prediction Label : {pred_label}")
# Out:
# Data 0 : Original Label stop, Prediction Label : stop
# Data 1 : Original Label down, Prediction Label : down
# Data 2 : Original Label up, Prediction Label : up
# Data 3 : Original Label right, Prediction Label : right
# Data 4 : Original Label stop, Prediction Label : stop
# Data 5 : Original Label off, Prediction Label : off
# Data 6 : Original Label stop, Prediction Label : stop
# Data 7 : Original Label down, Prediction Label : stop
# Data 8 : Original Label on, Prediction Label : on
# Data 9 : Original Label left, Prediction Label : left
# Data 10 : Original Label up, Prediction Label : up
# Data 11 : Original Label down, Prediction Label : down
# Data 12 : Original Label down, Prediction Label : down
# Data 13 : Original Label on, Prediction Label : on
# Data 14 : Original Label up, Prediction Label : up
# Data 15 : Original Label up, Prediction Label : up
# Data 16 : Original Label down, Prediction Label : down
# Data 17 : Original Label on, Prediction Label : on
# Data 18 : Original Label off, Prediction Label : off
# Data 19 : Original Label stop, Prediction Label : stop
# Data 20 : Original Label up, Prediction Label : up
# Data 21 : Original Label up, Prediction Label : up
# Data 22 : Original Label on, Prediction Label : on
# Data 23 : Original Label on, Prediction Label : on
# Data 24 : Original Label off, Prediction Label : off
# Data 25 : Original Label stop, Prediction Label : stop
# Data 26 : Original Label right, Prediction Label : right
# Data 27 : Original Label on, Prediction Label : on
# Data 28 : Original Label up, Prediction Label : up
# Data 29 : Original Label off, Prediction Label : up
# Data 30 : Original Label on, Prediction Label : on
# Data 31 : Original Label up, Prediction Label : up
# Data 32 : Original Label off, Prediction Label : off
# Data 33 : Original Label stop, Prediction Label : stop
# Data 34 : Original Label off, Prediction Label : off
# Data 35 : Original Label down, Prediction Label : down
# Data 36 : Original Label off, Prediction Label : off
# Data 37 : Original Label down, Prediction Label : down
# Data 38 : Original Label down, Prediction Label : down
# Data 39 : Original Label stop, Prediction Label : stop
# Data 40 : Original Label stop, Prediction Label : stop
# Data 41 : Original Label on, Prediction Label : on
# Data 42 : Original Label down, Prediction Label : down
# Data 43 : Original Label left, Prediction Label : left
# Data 44 : Original Label stop, Prediction Label : stop
# Data 45 : Original Label off, Prediction Label : off
# Data 46 : Original Label up, Prediction Label : up
# Data 47 : Original Label right, Prediction Label : right
# Data 48 : Original Label on, Prediction Label : on
# Data 49 : Original Label off, Prediction Label : up
# Data 50 : Original Label down, Prediction Label : down
# Data 51 : Original Label left, Prediction Label : left
# Data 52 : Original Label stop, Prediction Label : off
# Data 53 : Original Label down, Prediction Label : down
# Data 54 : Original Label left, Prediction Label : up
# Data 55 : Original Label on, Prediction Label : on
# Data 56 : Original Label on, Prediction Label : on
# Data 57 : Original Label left, Prediction Label : left
# Data 58 : Original Label on, Prediction Label : on
# Data 59 : Original Label stop, Prediction Label : stop
# Data 60 : Original Label right, Prediction Label : right
# Data 61 : Original Label down, Prediction Label : down
# Data 62 : Original Label right, Prediction Label : right
# Data 63 : Original Label up, Prediction Label : up
# Data 64 : Original Label off, Prediction Label : up
# Data 65 : Original Label on, Prediction Label : on
# Data 66 : Original Label stop, Prediction Label : stop
# Data 67 : Original Label right, Prediction Label : right
# Data 68 : Original Label stop, Prediction Label : stop
# Data 69 : Original Label down, Prediction Label : down
# Data 70 : Original Label stop, Prediction Label : stop
# Data 71 : Original Label stop, Prediction Label : stop
# Data 72 : Original Label down, Prediction Label : down
# Data 73 : Original Label down, Prediction Label : down
# Data 74 : Original Label down, Prediction Label : on
# Data 75 : Original Label off, Prediction Label : off
# Data 76 : Original Label down, Prediction Label : down
# Data 77 : Original Label stop, Prediction Label : stop
# Data 78 : Original Label on, Prediction Label : on
# Data 79 : Original Label stop, Prediction Label : stop
# Data 80 : Original Label off, Prediction Label : off
# Data 81 : Original Label off, Prediction Label : off
# Data 82 : Original Label stop, Prediction Label : stop
# Data 83 : Original Label up, Prediction Label : up
# Data 84 : Original Label on, Prediction Label : on
# Data 85 : Original Label off, Prediction Label : off
# Data 86 : Original Label off, Prediction Label : off
# Data 87 : Original Label up, Prediction Label : left
# Data 88 : Original Label right, Prediction Label : right
# Data 89 : Original Label right, Prediction Label : right
# Data 90 : Original Label right, Prediction Label : right
# Data 91 : Original Label up, Prediction Label : up
# Data 92 : Original Label stop, Prediction Label : stop
# Data 93 : Original Label down, Prediction Label : down
# Data 94 : Original Label off, Prediction Label : up
# Data 95 : Original Label stop, Prediction Label : stop
# Data 96 : Original Label on, Prediction Label : on
# Data 97 : Original Label down, Prediction Label : down
# Data 98 : Original Label off, Prediction Label : off
# Data 99 : Original Label left, Prediction Label : stop
# Data 100 : Original Label stop, Prediction Label : stop
# Data 101 : Original Label on, Prediction Label : on
# Data 102 : Original Label left, Prediction Label : left
# Data 103 : Original Label stop, Prediction Label : stop
# Data 104 : Original Label left, Prediction Label : left
# Data 105 : Original Label left, Prediction Label : left
# Data 106 : Original Label down, Prediction Label : down
# Data 107 : Original Label left, Prediction Label : left
# Data 108 : Original Label stop, Prediction Label : stop
# Data 109 : Original Label on, Prediction Label : on
# Data 110 : Original Label off, Prediction Label : off
# Data 111 : Original Label stop, Prediction Label : stop
# Data 112 : Original Label stop, Prediction Label : stop
# Data 113 : Original Label off, Prediction Label : off
# Data 114 : Original Label right, Prediction Label : right
# Data 115 : Original Label on, Prediction Label : on
# Data 116 : Original Label up, Prediction Label : up
# Data 117 : Original Label up, Prediction Label : up
# Data 118 : Original Label left, Prediction Label : left
# Data 119 : Original Label right, Prediction Label : right
# Data 120 : Original Label down, Prediction Label : down
# Data 121 : Original Label off, Prediction Label : off
# Data 122 : Original Label off, Prediction Label : off
# Data 123 : Original Label left, Prediction Label : left
# Data 124 : Original Label down, Prediction Label : down
# Data 125 : Original Label down, Prediction Label : down
# Data 126 : Original Label up, Prediction Label : up
# Data 127 : Original Label on, Prediction Label : on
# Data 128 : Original Label off, Prediction Label : off
# Data 129 : Original Label right, Prediction Label : right
# Data 130 : Original Label down, Prediction Label : down
# Data 131 : Original Label left, Prediction Label : up
# Data 132 : Original Label right, Prediction Label : right
# Data 133 : Original Label down, Prediction Label : down
# Data 134 : Original Label right, Prediction Label : right
# Data 135 : Original Label right, Prediction Label : up
# Data 136 : Original Label up, Prediction Label : up
# Data 137 : Original Label on, Prediction Label : on
# Data 138 : Original Label stop, Prediction Label : stop
# Data 139 : Original Label down, Prediction Label : down
# Data 140 : Original Label stop, Prediction Label : stop
# Data 141 : Original Label left, Prediction Label : up
# Data 142 : Original Label stop, Prediction Label : stop
# Data 143 : Original Label right, Prediction Label : right
# Data 144 : Original Label down, Prediction Label : down
# Data 145 : Original Label stop, Prediction Label : stop
# Data 146 : Original Label up, Prediction Label : up
# Data 147 : Original Label right, Prediction Label : left
# Data 148 : Original Label on, Prediction Label : on
# Data 149 : Original Label on, Prediction Label : on
# Data 150 : Original Label down, Prediction Label : down
# Data 151 : Original Label stop, Prediction Label : stop
# Data 152 : Original Label right, Prediction Label : right
# Data 153 : Original Label down, Prediction Label : down
# Data 154 : Original Label down, Prediction Label : down
# Data 155 : Original Label down, Prediction Label : down
# Data 156 : Original Label down, Prediction Label : down
# Data 157 : Original Label left, Prediction Label : left
# Data 158 : Original Label off, Prediction Label : off
# Data 159 : Original Label on, Prediction Label : on
# Data 160 : Original Label down, Prediction Label : down
# Data 161 : Original Label off, Prediction Label : off
# Data 162 : Original Label left, Prediction Label : left
# Data 163 : Original Label off, Prediction Label : off
# Data 164 : Original Label right, Prediction Label : right
# Data 165 : Original Label up, Prediction Label : up
# Data 166 : Original Label on, Prediction Label : on
# Data 167 : Original Label left, Prediction Label : left
# Data 168 : Original Label down, Prediction Label : down
# Data 169 : Original Label off, Prediction Label : off
# Data 170 : Original Label right, Prediction Label : right
# Data 171 : Original Label up, Prediction Label : up
# Data 172 : Original Label off, Prediction Label : off
# Data 173 : Original Label up, Prediction Label : up
# Data 174 : Original Label down, Prediction Label : down
# Data 175 : Original Label left, Prediction Label : left
# Data 176 : Original Label up, Prediction Label : up
# Data 177 : Original Label stop, Prediction Label : stop
# Data 178 : Original Label left, Prediction Label : left
# Data 179 : Original Label stop, Prediction Label : stop
# Data 180 : Original Label left, Prediction Label : left
# Data 181 : Original Label right, Prediction Label : right
# Data 182 : Original Label stop, Prediction Label : stop
# Data 183 : Original Label off, Prediction Label : off
# Data 184 : Original Label left, Prediction Label : left
# Data 185 : Original Label up, Prediction Label : stop
# Data 186 : Original Label on, Prediction Label : on
# Data 187 : Original Label left, Prediction Label : left
# Data 188 : Original Label off, Prediction Label : off
# Data 189 : Original Label down, Prediction Label : down
# Data 190 : Original Label right, Prediction Label : right
# Data 191 : Original Label off, Prediction Label : off
# Data 192 : Original Label left, Prediction Label : left
# Data 193 : Original Label down, Prediction Label : off
# Data 194 : Original Label down, Prediction Label : down
# Data 195 : Original Label off, Prediction Label : off
# Data 196 : Original Label up, Prediction Label : off
# Data 197 : Original Label stop, Prediction Label : stop
# Data 198 : Original Label off, Prediction Label : off
# Data 199 : Original Label down, Prediction Label : down
# Data 200 : Original Label on, Prediction Label : on
# Data 201 : Original Label on, Prediction Label : on
# Data 202 : Original Label on, Prediction Label : on
# Data 203 : Original Label right, Prediction Label : right
# Data 204 : Original Label off, Prediction Label : off
# Data 205 : Original Label stop, Prediction Label : stop
# Data 206 : Original Label up, Prediction Label : up
# Data 207 : Original Label up, Prediction Label : off
# Data 208 : Original Label off, Prediction Label : off
# Data 209 : Original Label right, Prediction Label : right
# Data 210 : Original Label down, Prediction Label : down
# Data 211 : Original Label off, Prediction Label : off
# Data 212 : Original Label on, Prediction Label : on
# Data 213 : Original Label right, Prediction Label : up
# Data 214 : Original Label stop, Prediction Label : stop
# Data 215 : Original Label on, Prediction Label : off
# Data 216 : Original Label on, Prediction Label : off
# Data 217 : Original Label up, Prediction Label : up
# Data 218 : Original Label on, Prediction Label : on
# Data 219 : Original Label stop, Prediction Label : stop
# Data 220 : Original Label stop, Prediction Label : stop
# Data 221 : Original Label on, Prediction Label : on
# Data 222 : Original Label down, Prediction Label : down
# Data 223 : Original Label right, Prediction Label : right
# Data 224 : Original Label left, Prediction Label : left
# Data 225 : Original Label up, Prediction Label : up
# Data 226 : Original Label on, Prediction Label : on
# Data 227 : Original Label right, Prediction Label : right
# Data 228 : Original Label down, Prediction Label : down
# Data 229 : Original Label on, Prediction Label : on
# Data 230 : Original Label on, Prediction Label : on
# Data 231 : Original Label right, Prediction Label : right
# Data 232 : Original Label off, Prediction Label : off
# Data 233 : Original Label down, Prediction Label : down
# Data 234 : Original Label right, Prediction Label : right
# Data 235 : Original Label on, Prediction Label : on
# Data 236 : Original Label stop, Prediction Label : stop
# Data 237 : Original Label off, Prediction Label : off
# Data 238 : Original Label on, Prediction Label : on
# Data 239 : Original Label left, Prediction Label : right
# Data 240 : Original Label down, Prediction Label : down
# Data 241 : Original Label left, Prediction Label : left
# Data 242 : Original Label left, Prediction Label : left
# Data 243 : Original Label stop, Prediction Label : stop
# Data 244 : Original Label left, Prediction Label : left
# Data 245 : Original Label up, Prediction Label : up
# Data 246 : Original Label stop, Prediction Label : stop
# Data 247 : Original Label off, Prediction Label : off
# Data 248 : Original Label left, Prediction Label : left
# Data 249 : Original Label down, Prediction Label : down
# Data 250 : Original Label off, Prediction Label : stop
# Data 251 : Original Label off, Prediction Label : off
# Data 252 : Original Label off, Prediction Label : off
# Data 253 : Original Label left, Prediction Label : left
# Data 254 : Original Label left, Prediction Label : left
# Data 255 : Original Label down, Prediction Label : down
# Data 256 : Original Label left, Prediction Label : left
# Data 257 : Original Label off, Prediction Label : off
# Data 258 : Original Label left, Prediction Label : left
# Data 259 : Original Label on, Prediction Label : on
# Data 260 : Original Label stop, Prediction Label : stop
# Data 261 : Original Label up, Prediction Label : up
# Data 262 : Original Label on, Prediction Label : on
# Data 263 : Original Label off, Prediction Label : off
# Data 264 : Original Label left, Prediction Label : left
# Data 265 : Original Label left, Prediction Label : left
# Data 266 : Original Label left, Prediction Label : left
# Data 267 : Original Label down, Prediction Label : down
# Data 268 : Original Label off, Prediction Label : off
# Data 269 : Original Label stop, Prediction Label : stop
# Data 270 : Original Label right, Prediction Label : right
# Data 271 : Original Label stop, Prediction Label : stop
# Data 272 : Original Label left, Prediction Label : left
# Data 273 : Original Label up, Prediction Label : up
# Data 274 : Original Label right, Prediction Label : right
# Data 275 : Original Label on, Prediction Label : on
# Data 276 : Original Label left, Prediction Label : left
# Data 277 : Original Label on, Prediction Label : on
# Data 278 : Original Label up, Prediction Label : up
# Data 279 : Original Label down, Prediction Label : stop
# Data 280 : Original Label off, Prediction Label : off
# Data 281 : Original Label up, Prediction Label : up
# Data 282 : Original Label right, Prediction Label : right
# Data 283 : Original Label off, Prediction Label : off
# Data 284 : Original Label off, Prediction Label : off
# Data 285 : Original Label off, Prediction Label : up
# Data 286 : Original Label right, Prediction Label : right
# Data 287 : Original Label on, Prediction Label : on
# Data 288 : Original Label off, Prediction Label : on
# Data 289 : Original Label stop, Prediction Label : up
# Data 290 : Original Label right, Prediction Label : right
# Data 291 : Original Label on, Prediction Label : on
# Data 292 : Original Label on, Prediction Label : on
# Data 293 : Original Label right, Prediction Label : right
# Data 294 : Original Label left, Prediction Label : left
# Data 295 : Original Label right, Prediction Label : right
# Data 296 : Original Label stop, Prediction Label : down
# Data 297 : Original Label down, Prediction Label : down
# Data 298 : Original Label off, Prediction Label : off
# Data 299 : Original Label down, Prediction Label : down
# Data 300 : Original Label stop, Prediction Label : stop
# Data 301 : Original Label off, Prediction Label : off
# Data 302 : Original Label stop, Prediction Label : stop
# Data 303 : Original Label stop, Prediction Label : stop
# Data 304 : Original Label stop, Prediction Label : stop
# Data 305 : Original Label right, Prediction Label : right
# Data 306 : Original Label down, Prediction Label : down
# Data 307 : Original Label down, Prediction Label : down
# Data 308 : Original Label right, Prediction Label : right
# Data 309 : Original Label stop, Prediction Label : stop
# Data 310 : Original Label left, Prediction Label : left
# Data 311 : Original Label down, Prediction Label : down
# Data 312 : Original Label down, Prediction Label : down
# Data 313 : Original Label on, Prediction Label : on
# Data 314 : Original Label off, Prediction Label : up
# Data 315 : Original Label stop, Prediction Label : off
# Data 316 : Original Label up, Prediction Label : up
# Data 317 : Original Label stop, Prediction Label : stop
# Data 318 : Original Label stop, Prediction Label : stop
# Data 319 : Original Label off, Prediction Label : up
# Data 320 : Original Label off, Prediction Label : off
# Data 321 : Original Label stop, Prediction Label : stop
# Data 322 : Original Label off, Prediction Label : off
# Data 323 : Original Label right, Prediction Label : right
# Data 324 : Original Label left, Prediction Label : left
# Data 325 : Original Label left, Prediction Label : left
# Data 326 : Original Label stop, Prediction Label : stop
# Data 327 : Original Label left, Prediction Label : left
# Data 328 : Original Label on, Prediction Label : on
# Data 329 : Original Label down, Prediction Label : down
# Data 330 : Original Label off, Prediction Label : off
# Data 331 : Original Label right, Prediction Label : left
# Data 332 : Original Label on, Prediction Label : on
# Data 333 : Original Label right, Prediction Label : right
# Data 334 : Original Label up, Prediction Label : up
# Data 335 : Original Label on, Prediction Label : on
# Data 336 : Original Label down, Prediction Label : down
# Data 337 : Original Label left, Prediction Label : up
# Data 338 : Original Label right, Prediction Label : right
# Data 339 : Original Label stop, Prediction Label : stop
# Data 340 : Original Label left, Prediction Label : left
# Data 341 : Original Label right, Prediction Label : right
# Data 342 : Original Label off, Prediction Label : off
# Data 343 : Original Label up, Prediction Label : up
# Data 344 : Original Label up, Prediction Label : up
# Data 345 : Original Label stop, Prediction Label : stop
# Data 346 : Original Label down, Prediction Label : down
# Data 347 : Original Label stop, Prediction Label : stop
# Data 348 : Original Label stop, Prediction Label : stop
# Data 349 : Original Label down, Prediction Label : down
# Data 350 : Original Label off, Prediction Label : off
# Data 351 : Original Label stop, Prediction Label : stop
# Data 352 : Original Label up, Prediction Label : off
# Data 353 : Original Label up, Prediction Label : up
# Data 354 : Original Label up, Prediction Label : up
# Data 355 : Original Label up, Prediction Label : up
# Data 356 : Original Label on, Prediction Label : on
# Data 357 : Original Label down, Prediction Label : down
# Data 358 : Original Label right, Prediction Label : right
# Data 359 : Original Label down, Prediction Label : down
# Data 360 : Original Label right, Prediction Label : right
# Data 361 : Original Label on, Prediction Label : on
# Data 362 : Original Label up, Prediction Label : up
# Data 363 : Original Label on, Prediction Label : on
# Data 364 : Original Label up, Prediction Label : up
# Data 365 : Original Label left, Prediction Label : left
# Data 366 : Original Label up, Prediction Label : up
# Data 367 : Original Label off, Prediction Label : up
# Data 368 : Original Label on, Prediction Label : on
# Data 369 : Original Label off, Prediction Label : off
# Data 370 : Original Label right, Prediction Label : right
# Data 371 : Original Label up, Prediction Label : up
# Data 372 : Original Label up, Prediction Label : up
# Data 373 : Original Label left, Prediction Label : left
# Data 374 : Original Label right, Prediction Label : right
# Data 375 : Original Label stop, Prediction Label : stop
# Data 376 : Original Label right, Prediction Label : right
# Data 377 : Original Label off, Prediction Label : off
# Data 378 : Original Label on, Prediction Label : off
# Data 379 : Original Label on, Prediction Label : on
# Data 380 : Original Label up, Prediction Label : up
# Data 381 : Original Label stop, Prediction Label : stop
# Data 382 : Original Label left, Prediction Label : left
# Data 383 : Original Label left, Prediction Label : left
# Data 384 : Original Label up, Prediction Label : up
# Data 385 : Original Label left, Prediction Label : left
# Data 386 : Original Label down, Prediction Label : down
# Data 387 : Original Label up, Prediction Label : up
# Data 388 : Original Label down, Prediction Label : down
# Data 389 : Original Label right, Prediction Label : right
# Data 390 : Original Label stop, Prediction Label : stop
# Data 391 : Original Label on, Prediction Label : on
# Data 392 : Original Label on, Prediction Label : off
# Data 393 : Original Label on, Prediction Label : left
# Data 394 : Original Label right, Prediction Label : right
# Data 395 : Original Label right, Prediction Label : left
# Data 396 : Original Label on, Prediction Label : off
# Data 397 : Original Label right, Prediction Label : right
# Data 398 : Original Label left, Prediction Label : left
# Data 399 : Original Label on, Prediction Label : on
# Data 400 : Original Label down, Prediction Label : down
# Data 401 : Original Label off, Prediction Label : off
# Data 402 : Original Label right, Prediction Label : right
# Data 403 : Original Label stop, Prediction Label : stop
# Data 404 : Original Label up, Prediction Label : off
# Data 405 : Original Label left, Prediction Label : left
# Data 406 : Original Label left, Prediction Label : left
# Data 407 : Original Label down, Prediction Label : down
# Data 408 : Original Label left, Prediction Label : left
# Data 409 : Original Label right, Prediction Label : right
# Data 410 : Original Label up, Prediction Label : up
# Data 411 : Original Label right, Prediction Label : right
# Data 412 : Original Label on, Prediction Label : on
# Data 413 : Original Label left, Prediction Label : left
# Data 414 : Original Label on, Prediction Label : on
# Data 415 : Original Label down, Prediction Label : down
# Data 416 : Original Label off, Prediction Label : off
# Data 417 : Original Label right, Prediction Label : right
# Data 418 : Original Label left, Prediction Label : left
# Data 419 : Original Label on, Prediction Label : on
# Data 420 : Original Label on, Prediction Label : off
# Data 421 : Original Label down, Prediction Label : down
# Data 422 : Original Label stop, Prediction Label : stop
# Data 423 : Original Label up, Prediction Label : up
# Data 424 : Original Label down, Prediction Label : down
# Data 425 : Original Label up, Prediction Label : up
# Data 426 : Original Label on, Prediction Label : on
# Data 427 : Original Label up, Prediction Label : up
# Data 428 : Original Label off, Prediction Label : off
# Data 429 : Original Label off, Prediction Label : off
# Data 430 : Original Label right, Prediction Label : off
# Data 431 : Original Label up, Prediction Label : up
# Data 432 : Original Label on, Prediction Label : on
# Data 433 : Original Label up, Prediction Label : up
# Data 434 : Original Label down, Prediction Label : down
# Data 435 : Original Label left, Prediction Label : left
# Data 436 : Original Label on, Prediction Label : on
# Data 437 : Original Label up, Prediction Label : up
# Data 438 : Original Label right, Prediction Label : right
# Data 439 : Original Label stop, Prediction Label : up
# Data 440 : Original Label down, Prediction Label : down
# Data 441 : Original Label off, Prediction Label : off
# Data 442 : Original Label left, Prediction Label : left
# Data 443 : Original Label down, Prediction Label : down
# Data 444 : Original Label up, Prediction Label : up
# Data 445 : Original Label left, Prediction Label : left
# Data 446 : Original Label on, Prediction Label : on
# Data 447 : Original Label down, Prediction Label : down
# Data 448 : Original Label left, Prediction Label : left
# Data 449 : Original Label up, Prediction Label : up
# Data 450 : Original Label off, Prediction Label : off
# Data 451 : Original Label left, Prediction Label : left
# Data 452 : Original Label left, Prediction Label : left
# Data 453 : Original Label left, Prediction Label : left
# Data 454 : Original Label off, Prediction Label : off
# Data 455 : Original Label left, Prediction Label : off
# Data 456 : Original Label down, Prediction Label : down
# Data 457 : Original Label on, Prediction Label : on
# Data 458 : Original Label down, Prediction Label : down
# Data 459 : Original Label up, Prediction Label : up
# Data 460 : Original Label up, Prediction Label : up
# Data 461 : Original Label off, Prediction Label : off
# Data 462 : Original Label stop, Prediction Label : stop
# Data 463 : Original Label right, Prediction Label : right
# Data 464 : Original Label down, Prediction Label : down
# Data 465 : Original Label stop, Prediction Label : stop
# Data 466 : Original Label left, Prediction Label : left
# Data 467 : Original Label stop, Prediction Label : stop
# Data 468 : Original Label up, Prediction Label : up
# Data 469 : Original Label on, Prediction Label : off
# Data 470 : Original Label down, Prediction Label : down
# Data 471 : Original Label off, Prediction Label : off
# Data 472 : Original Label up, Prediction Label : left
# Data 473 : Original Label on, Prediction Label : on
# Data 474 : Original Label on, Prediction Label : on
# Data 475 : Original Label right, Prediction Label : up
# Data 476 : Original Label right, Prediction Label : right
# Data 477 : Original Label off, Prediction Label : off
# Data 478 : Original Label left, Prediction Label : left
# Data 479 : Original Label left, Prediction Label : left
# Data 480 : Original Label stop, Prediction Label : stop
# Data 481 : Original Label on, Prediction Label : on
# Data 482 : Original Label up, Prediction Label : up
# Data 483 : Original Label left, Prediction Label : left
# Data 484 : Original Label on, Prediction Label : on
# Data 485 : Original Label stop, Prediction Label : stop
# Data 486 : Original Label off, Prediction Label : off
# Data 487 : Original Label stop, Prediction Label : stop
# Data 488 : Original Label left, Prediction Label : left
# Data 489 : Original Label off, Prediction Label : off
# Data 490 : Original Label down, Prediction Label : down
# Data 491 : Original Label off, Prediction Label : off
# Data 492 : Original Label right, Prediction Label : right
# Data 493 : Original Label left, Prediction Label : left
# Data 494 : Original Label up, Prediction Label : up
# Data 495 : Original Label on, Prediction Label : on
# Data 496 : Original Label on, Prediction Label : on
# Data 497 : Original Label off, Prediction Label : off
# Data 498 : Original Label stop, Prediction Label : stop
# Data 499 : Original Label stop, Prediction Label : stop
# Data 500 : Original Label off, Prediction Label : up
# Data 501 : Original Label up, Prediction Label : up
# Data 502 : Original Label up, Prediction Label : up
# Data 503 : Original Label stop, Prediction Label : stop
# Data 504 : Original Label on, Prediction Label : on
# Data 505 : Original Label down, Prediction Label : down
# Data 506 : Original Label up, Prediction Label : up
# Data 507 : Original Label stop, Prediction Label : stop
# Data 508 : Original Label up, Prediction Label : up
# Data 509 : Original Label down, Prediction Label : down
# Data 510 : Original Label off, Prediction Label : off
# Data 511 : Original Label up, Prediction Label : up
# Data 512 : Original Label up, Prediction Label : up
# Data 513 : Original Label off, Prediction Label : off
# Data 514 : Original Label right, Prediction Label : right
# Data 515 : Original Label up, Prediction Label : up
# Data 516 : Original Label off, Prediction Label : off
# Data 517 : Original Label left, Prediction Label : left
# Data 518 : Original Label left, Prediction Label : left
# Data 519 : Original Label down, Prediction Label : down
# Data 520 : Original Label down, Prediction Label : down
# Data 521 : Original Label down, Prediction Label : down
# Data 522 : Original Label right, Prediction Label : right
# Data 523 : Original Label up, Prediction Label : up
# Data 524 : Original Label down, Prediction Label : down
# Data 525 : Original Label off, Prediction Label : off
# Data 526 : Original Label up, Prediction Label : left
# Data 527 : Original Label off, Prediction Label : off
# Data 528 : Original Label off, Prediction Label : off
# Data 529 : Original Label stop, Prediction Label : stop
# Data 530 : Original Label right, Prediction Label : right
# Data 531 : Original Label stop, Prediction Label : stop
# Data 532 : Original Label off, Prediction Label : off
# Data 533 : Original Label down, Prediction Label : down
# Data 534 : Original Label right, Prediction Label : up
# Data 535 : Original Label off, Prediction Label : off
# Data 536 : Original Label right, Prediction Label : right
# Data 537 : Original Label stop, Prediction Label : stop
# Data 538 : Original Label left, Prediction Label : left
# Data 539 : Original Label stop, Prediction Label : stop
# Data 540 : Original Label on, Prediction Label : on
# Data 541 : Original Label up, Prediction Label : up
# Data 542 : Original Label up, Prediction Label : up
# Data 543 : Original Label left, Prediction Label : left
# Data 544 : Original Label down, Prediction Label : down
# Data 545 : Original Label off, Prediction Label : off
# Data 546 : Original Label stop, Prediction Label : left
# Data 547 : Original Label off, Prediction Label : off
# Data 548 : Original Label off, Prediction Label : off
# Data 549 : Original Label off, Prediction Label : off
# Data 550 : Original Label up, Prediction Label : up
# Data 551 : Original Label left, Prediction Label : left
# Data 552 : Original Label up, Prediction Label : up
# Data 553 : Original Label right, Prediction Label : right
# Data 554 : Original Label up, Prediction Label : up
# Data 555 : Original Label left, Prediction Label : left
# Data 556 : Original Label left, Prediction Label : left
# Data 557 : Original Label left, Prediction Label : left
# Data 558 : Original Label on, Prediction Label : off
# Data 559 : Original Label left, Prediction Label : left
# Data 560 : Original Label left, Prediction Label : left
# Data 561 : Original Label on, Prediction Label : on
# Data 562 : Original Label down, Prediction Label : down
# Data 563 : Original Label up, Prediction Label : off
# Data 564 : Original Label left, Prediction Label : left
# Data 565 : Original Label stop, Prediction Label : stop
# Data 566 : Original Label off, Prediction Label : off
# Data 567 : Original Label up, Prediction Label : up
# Data 568 : Original Label down, Prediction Label : down
# Data 569 : Original Label down, Prediction Label : down
# Data 570 : Original Label up, Prediction Label : up
# Data 571 : Original Label right, Prediction Label : right
# Data 572 : Original Label up, Prediction Label : up
# Data 573 : Original Label up, Prediction Label : up
# Data 574 : Original Label right, Prediction Label : right
# Data 575 : Original Label up, Prediction Label : up
# Data 576 : Original Label on, Prediction Label : on
# Data 577 : Original Label on, Prediction Label : on
# Data 578 : Original Label on, Prediction Label : on
# Data 579 : Original Label left, Prediction Label : up
# Data 580 : Original Label up, Prediction Label : up
# Data 581 : Original Label on, Prediction Label : on
# Data 582 : Original Label right, Prediction Label : right
# Data 583 : Original Label left, Prediction Label : left
# Data 584 : Original Label off, Prediction Label : off
# Data 585 : Original Label up, Prediction Label : up
# Data 586 : Original Label on, Prediction Label : on
# Data 587 : Original Label down, Prediction Label : down
# Data 588 : Original Label off, Prediction Label : off
# Data 589 : Original Label stop, Prediction Label : stop
# Data 590 : Original Label left, Prediction Label : left
# Data 591 : Original Label off, Prediction Label : off
# Data 592 : Original Label up, Prediction Label : up
# Data 593 : Original Label left, Prediction Label : left
# Data 594 : Original Label left, Prediction Label : left
# Data 595 : Original Label up, Prediction Label : up
# Data 596 : Original Label down, Prediction Label : down
# Data 597 : Original Label right, Prediction Label : right
# Data 598 : Original Label stop, Prediction Label : stop
# Data 599 : Original Label down, Prediction Label : down
# Data 600 : Original Label off, Prediction Label : left
# Data 601 : Original Label off, Prediction Label : off
# Data 602 : Original Label on, Prediction Label : on
# Data 603 : Original Label off, Prediction Label : off
# Data 604 : Original Label left, Prediction Label : left
# Data 605 : Original Label off, Prediction Label : off
# Data 606 : Original Label down, Prediction Label : down
# Data 607 : Original Label stop, Prediction Label : stop
# Data 608 : Original Label stop, Prediction Label : stop
# Data 609 : Original Label up, Prediction Label : up
# Data 610 : Original Label off, Prediction Label : off
# Data 611 : Original Label up, Prediction Label : up
# Data 612 : Original Label right, Prediction Label : right
# Data 613 : Original Label off, Prediction Label : off
# Data 614 : Original Label off, Prediction Label : off
# Data 615 : Original Label on, Prediction Label : on
# Data 616 : Original Label stop, Prediction Label : stop
# Data 617 : Original Label down, Prediction Label : down
# Data 618 : Original Label on, Prediction Label : on
# Data 619 : Original Label left, Prediction Label : left
# Data 620 : Original Label stop, Prediction Label : stop
# Data 621 : Original Label right, Prediction Label : right
# Data 622 : Original Label off, Prediction Label : off
# Data 623 : Original Label right, Prediction Label : right
# Data 624 : Original Label right, Prediction Label : right
# Data 625 : Original Label right, Prediction Label : right
# Data 626 : Original Label on, Prediction Label : off
# Data 627 : Original Label on, Prediction Label : on
# Data 628 : Original Label off, Prediction Label : off
# Data 629 : Original Label right, Prediction Label : right
# Data 630 : Original Label down, Prediction Label : down
# Data 631 : Original Label stop, Prediction Label : stop
# Data 632 : Original Label stop, Prediction Label : stop
# Data 633 : Original Label on, Prediction Label : on
# Data 634 : Original Label on, Prediction Label : on
# Data 635 : Original Label left, Prediction Label : left
# Data 636 : Original Label up, Prediction Label : up
# Data 637 : Original Label on, Prediction Label : on
# Data 638 : Original Label left, Prediction Label : off
# Data 639 : Original Label down, Prediction Label : down
# Data 640 : Original Label right, Prediction Label : right
# Data 641 : Original Label right, Prediction Label : right
# Data 642 : Original Label left, Prediction Label : left
# Data 643 : Original Label stop, Prediction Label : stop
# Data 644 : Original Label up, Prediction Label : up
# Data 645 : Original Label down, Prediction Label : down
# Data 646 : Original Label down, Prediction Label : down
# Data 647 : Original Label up, Prediction Label : up
# Data 648 : Original Label stop, Prediction Label : stop
# Data 649 : Original Label up, Prediction Label : up
# Data 650 : Original Label left, Prediction Label : left
# Data 651 : Original Label down, Prediction Label : down
# Data 652 : Original Label on, Prediction Label : on
# Data 653 : Original Label on, Prediction Label : on
# Data 654 : Original Label up, Prediction Label : up
# Data 655 : Original Label stop, Prediction Label : stop
# Data 656 : Original Label stop, Prediction Label : stop
# Data 657 : Original Label on, Prediction Label : on
# Data 658 : Original Label up, Prediction Label : up
# Data 659 : Original Label up, Prediction Label : up
# Data 660 : Original Label right, Prediction Label : right
# Data 661 : Original Label on, Prediction Label : on
# Data 662 : Original Label left, Prediction Label : left
# Data 663 : Original Label stop, Prediction Label : stop
# Data 664 : Original Label on, Prediction Label : on
# Data 665 : Original Label stop, Prediction Label : up
# Data 666 : Original Label right, Prediction Label : right
# Data 667 : Original Label stop, Prediction Label : stop
# Data 668 : Original Label stop, Prediction Label : stop
# Data 669 : Original Label stop, Prediction Label : stop
# Data 670 : Original Label right, Prediction Label : right
# Data 671 : Original Label on, Prediction Label : on
# Data 672 : Original Label off, Prediction Label : up
# Data 673 : Original Label up, Prediction Label : left
# Data 674 : Original Label down, Prediction Label : down
# Data 675 : Original Label off, Prediction Label : off
# Data 676 : Original Label down, Prediction Label : down
# Data 677 : Original Label left, Prediction Label : left
# Data 678 : Original Label off, Prediction Label : off
# Data 679 : Original Label stop, Prediction Label : stop
# Data 680 : Original Label on, Prediction Label : on
# Data 681 : Original Label right, Prediction Label : left
# Data 682 : Original Label off, Prediction Label : off
# Data 683 : Original Label up, Prediction Label : up
# Data 684 : Original Label up, Prediction Label : stop
# Data 685 : Original Label down, Prediction Label : down
# Data 686 : Original Label left, Prediction Label : left
# Data 687 : Original Label down, Prediction Label : down
# Data 688 : Original Label up, Prediction Label : up
# Data 689 : Original Label right, Prediction Label : right
# Data 690 : Original Label on, Prediction Label : on
# Data 691 : Original Label down, Prediction Label : left
# Data 692 : Original Label left, Prediction Label : left
# Data 693 : Original Label down, Prediction Label : down
# Data 694 : Original Label stop, Prediction Label : stop
# Data 695 : Original Label on, Prediction Label : on
# Data 696 : Original Label left, Prediction Label : left
# Data 697 : Original Label on, Prediction Label : on
# Data 698 : Original Label stop, Prediction Label : stop
# Data 699 : Original Label down, Prediction Label : down
# Data 700 : Original Label on, Prediction Label : on
# Data 701 : Original Label on, Prediction Label : on
# Data 702 : Original Label on, Prediction Label : on
# Data 703 : Original Label off, Prediction Label : off
# Data 704 : Original Label off, Prediction Label : off
# Data 705 : Original Label right, Prediction Label : right
# Data 706 : Original Label right, Prediction Label : right
# Data 707 : Original Label down, Prediction Label : down
# Data 708 : Original Label stop, Prediction Label : up
# Data 709 : Original Label left, Prediction Label : left
# Data 710 : Original Label on, Prediction Label : on
# Data 711 : Original Label right, Prediction Label : left
# Data 712 : Original Label on, Prediction Label : on
# Data 713 : Original Label right, Prediction Label : right
# Data 714 : Original Label up, Prediction Label : up
# Data 715 : Original Label off, Prediction Label : up
# Data 716 : Original Label stop, Prediction Label : stop
# Data 717 : Original Label up, Prediction Label : up
# Data 718 : Original Label left, Prediction Label : left
# Data 719 : Original Label stop, Prediction Label : stop
# Data 720 : Original Label right, Prediction Label : right
# Data 721 : Original Label right, Prediction Label : on
# Data 722 : Original Label stop, Prediction Label : stop
# Data 723 : Original Label down, Prediction Label : down
# Data 724 : Original Label down, Prediction Label : down
# Data 725 : Original Label stop, Prediction Label : stop
# Data 726 : Original Label down, Prediction Label : down
# Data 727 : Original Label stop, Prediction Label : stop
# Data 728 : Original Label right, Prediction Label : right
# Data 729 : Original Label left, Prediction Label : left
# Data 730 : Original Label right, Prediction Label : right
# Data 731 : Original Label up, Prediction Label : up
# Data 732 : Original Label off, Prediction Label : off
# Data 733 : Original Label up, Prediction Label : up
# Data 734 : Original Label right, Prediction Label : right
# Data 735 : Original Label down, Prediction Label : down
# Data 736 : Original Label left, Prediction Label : left
# Data 737 : Original Label off, Prediction Label : off
# Data 738 : Original Label right, Prediction Label : right
# Data 739 : Original Label up, Prediction Label : up
# Data 740 : Original Label on, Prediction Label : on
# Data 741 : Original Label off, Prediction Label : up
# Data 742 : Original Label up, Prediction Label : up
# Data 743 : Original Label left, Prediction Label : left
# Data 744 : Original Label up, Prediction Label : up
# Data 745 : Original Label right, Prediction Label : right
# Data 746 : Original Label up, Prediction Label : up
# Data 747 : Original Label right, Prediction Label : right
# Data 748 : Original Label left, Prediction Label : right
# Data 749 : Original Label on, Prediction Label : on
# Data 750 : Original Label right, Prediction Label : right
# Data 751 : Original Label down, Prediction Label : down
# Data 752 : Original Label up, Prediction Label : up
# Data 753 : Original Label down, Prediction Label : down
# Data 754 : Original Label stop, Prediction Label : stop
# Data 755 : Original Label off, Prediction Label : off
# Data 756 : Original Label stop, Prediction Label : stop
# Data 757 : Original Label right, Prediction Label : right
# Data 758 : Original Label on, Prediction Label : on
# Data 759 : Original Label off, Prediction Label : stop
# Data 760 : Original Label up, Prediction Label : up
# Data 761 : Original Label right, Prediction Label : right
# Data 762 : Original Label stop, Prediction Label : stop
# Data 763 : Original Label right, Prediction Label : right
# Data 764 : Original Label off, Prediction Label : off
# Data 765 : Original Label left, Prediction Label : left
# Data 766 : Original Label left, Prediction Label : up
# Data 767 : Original Label left, Prediction Label : left
# Data 768 : Original Label left, Prediction Label : left
# Data 769 : Original Label up, Prediction Label : up
# Data 770 : Original Label on, Prediction Label : on
# Data 771 : Original Label off, Prediction Label : off
# Data 772 : Original Label stop, Prediction Label : stop
# Data 773 : Original Label stop, Prediction Label : stop
# Data 774 : Original Label down, Prediction Label : stop
# Data 775 : Original Label left, Prediction Label : left
# Data 776 : Original Label up, Prediction Label : up
# Data 777 : Original Label down, Prediction Label : down
# Data 778 : Original Label off, Prediction Label : off
# Data 779 : Original Label up, Prediction Label : up
# Data 780 : Original Label on, Prediction Label : on
# Data 781 : Original Label off, Prediction Label : off
# Data 782 : Original Label up, Prediction Label : up
# Data 783 : Original Label stop, Prediction Label : stop
# Data 784 : Original Label left, Prediction Label : left
# Data 785 : Original Label up, Prediction Label : up
# Data 786 : Original Label down, Prediction Label : down
# Data 787 : Original Label off, Prediction Label : off
# Data 788 : Original Label left, Prediction Label : left
# Data 789 : Original Label down, Prediction Label : off
# Data 790 : Original Label left, Prediction Label : left
# Data 791 : Original Label up, Prediction Label : off
# Data 792 : Original Label left, Prediction Label : left
# Data 793 : Original Label up, Prediction Label : up
# Data 794 : Original Label left, Prediction Label : left
# Data 795 : Original Label up, Prediction Label : up
# Data 796 : Original Label stop, Prediction Label : stop
# Data 797 : Original Label left, Prediction Label : left
# Data 798 : Original Label down, Prediction Label : down
# Data 799 : Original Label right, Prediction Label : left
# Data 800 : Original Label right, Prediction Label : right
# Data 801 : Original Label down, Prediction Label : down
# Data 802 : Original Label up, Prediction Label : up
# Data 803 : Original Label stop, Prediction Label : stop
# Data 804 : Original Label on, Prediction Label : on
# Data 805 : Original Label off, Prediction Label : off
# Data 806 : Original Label up, Prediction Label : up
# Data 807 : Original Label on, Prediction Label : on
# Data 808 : Original Label up, Prediction Label : up
# Data 809 : Original Label on, Prediction Label : on
# Data 810 : Original Label down, Prediction Label : down
# Data 811 : Original Label off, Prediction Label : off
# Data 812 : Original Label right, Prediction Label : right
# Data 813 : Original Label down, Prediction Label : down
# Data 814 : Original Label up, Prediction Label : up
# Data 815 : Original Label down, Prediction Label : down
# Data 816 : Original Label stop, Prediction Label : stop
# Data 817 : Original Label down, Prediction Label : down
# Data 818 : Original Label stop, Prediction Label : stop
# Data 819 : Original Label left, Prediction Label : off
# Data 820 : Original Label on, Prediction Label : on
# Data 821 : Original Label off, Prediction Label : off
# Data 822 : Original Label right, Prediction Label : right
# Data 823 : Original Label right, Prediction Label : right
# Data 824 : Original Label down, Prediction Label : down
# Data 825 : Original Label stop, Prediction Label : stop
# Data 826 : Original Label up, Prediction Label : up
# Data 827 : Original Label stop, Prediction Label : stop
# Data 828 : Original Label on, Prediction Label : on
# Data 829 : Original Label off, Prediction Label : off
# Data 830 : Original Label right, Prediction Label : right
# Data 831 : Original Label stop, Prediction Label : stop
# Data 832 : Original Label right, Prediction Label : right
# Data 833 : Original Label off, Prediction Label : off
# Data 834 : Original Label left, Prediction Label : right
# Data 835 : Original Label stop, Prediction Label : stop
# Data 836 : Original Label left, Prediction Label : left
# Data 837 : Original Label stop, Prediction Label : stop
# Data 838 : Original Label down, Prediction Label : down
# Data 839 : Original Label up, Prediction Label : up
# Data 840 : Original Label left, Prediction Label : left
# Data 841 : Original Label off, Prediction Label : up
# Data 842 : Original Label right, Prediction Label : right
# Data 843 : Original Label right, Prediction Label : right
# Data 844 : Original Label stop, Prediction Label : stop
# Data 845 : Original Label off, Prediction Label : off
# Data 846 : Original Label up, Prediction Label : up
# Data 847 : Original Label down, Prediction Label : down
# Data 848 : Original Label stop, Prediction Label : stop
# Data 849 : Original Label left, Prediction Label : left
# Data 850 : Original Label right, Prediction Label : right
# Data 851 : Original Label up, Prediction Label : up
# Data 852 : Original Label right, Prediction Label : right
# Data 853 : Original Label up, Prediction Label : off
# Data 854 : Original Label left, Prediction Label : left
# Data 855 : Original Label left, Prediction Label : left
# Data 856 : Original Label right, Prediction Label : right
# Data 857 : Original Label down, Prediction Label : down
# Data 858 : Original Label left, Prediction Label : left
# Data 859 : Original Label down, Prediction Label : down
# Data 860 : Original Label stop, Prediction Label : stop
# Data 861 : Original Label down, Prediction Label : down
# Data 862 : Original Label left, Prediction Label : left
# Data 863 : Original Label off, Prediction Label : off
# Data 864 : Original Label down, Prediction Label : down
# Data 865 : Original Label left, Prediction Label : left
# Data 866 : Original Label off, Prediction Label : up
# Data 867 : Original Label left, Prediction Label : up
# Data 868 : Original Label right, Prediction Label : right
# Data 869 : Original Label right, Prediction Label : right
# Data 870 : Original Label down, Prediction Label : on
# Data 871 : Original Label left, Prediction Label : left
# Data 872 : Original Label stop, Prediction Label : stop
# Data 873 : Original Label down, Prediction Label : down
# Data 874 : Original Label right, Prediction Label : right
# Data 875 : Original Label up, Prediction Label : up
# Data 876 : Original Label left, Prediction Label : left
# ...
# Data 1378 : Original Label right, Prediction Label : right
# Data 1379 : Original Label on, Prediction Label : on
# Data 1380 : Original Label off, Prediction Label : up
# Data 1381 : Original Label left, Prediction Label : left
# Data 1382 : Original Label on, Prediction Label : on
# Data 1383 : Original Label up, Prediction Label : up
# Data 1384 : Original Label right, Prediction Label : right
# Data 1385 : Original Label down, Prediction Label : down
# Data 1386 : Original Label on, Prediction Label : on
# Data 1387 : Original Label off, Prediction Label : stop
# Data 1388 : Original Label stop, Prediction Label : stop
# Data 1389 : Original Label down, Prediction Label : down
# Data 1390 : Original Label down, Prediction Label : down
# Data 1391 : Original Label right, Prediction Label : right
# Data 1392 : Original Label down, Prediction Label : down
# Data 1393 : Original Label stop, Prediction Label : stop
# Data 1394 : Original Label up, Prediction Label : up
# Data 1395 : Original Label stop, Prediction Label : stop
# Data 1396 : Original Label right, Prediction Label : right
# Data 1397 : Original Label down, Prediction Label : down
# Data 1398 : Original Label left, Prediction Label : left
# Data 1399 : Original Label right, Prediction Label : right
# Data 1400 : Original Label down, Prediction Label : down
# Data 1401 : Original Label left, Prediction Label : left
# Data 1402 : Original Label off, Prediction Label : off
# Data 1403 : Original Label on, Prediction Label : on
# Data 1404 : Original Label stop, Prediction Label : stop
# Data 1405 : Original Label up, Prediction Label : off
# Data 1406 : Original Label off, Prediction Label : off
# Data 1407 : Original Label off, Prediction Label : off
# Data 1408 : Original Label right, Prediction Label : right
# Data 1409 : Original Label left, Prediction Label : left
# Data 1410 : Original Label left, Prediction Label : left
# Data 1411 : Original Label off, Prediction Label : off
# Data 1412 : Original Label left, Prediction Label : left
# Data 1413 : Original Label down, Prediction Label : down
# Data 1414 : Original Label up, Prediction Label : up
# Data 1415 : Original Label stop, Prediction Label : stop
# Data 1416 : Original Label right, Prediction Label : right
# Data 1417 : Original Label right, Prediction Label : right
# Data 1418 : Original Label on, Prediction Label : on
# Data 1419 : Original Label stop, Prediction Label : stop
# Data 1420 : Original Label on, Prediction Label : up
# Data 1421 : Original Label on, Prediction Label : off
# Data 1422 : Original Label off, Prediction Label : off
# Data 1423 : Original Label right, Prediction Label : right
# Data 1424 : Original Label left, Prediction Label : left
# Data 1425 : Original Label stop, Prediction Label : stop
# Data 1426 : Original Label left, Prediction Label : left
# Data 1427 : Original Label down, Prediction Label : down
# Data 1428 : Original Label on, Prediction Label : on
# Data 1429 : Original Label left, Prediction Label : left
# Data 1430 : Original Label left, Prediction Label : left
# Data 1431 : Original Label off, Prediction Label : off
# Data 1432 : Original Label left, Prediction Label : left
# Data 1433 : Original Label stop, Prediction Label : stop
# Data 1434 : Original Label stop, Prediction Label : stop
# Data 1435 : Original Label off, Prediction Label : off
# Data 1436 : Original Label up, Prediction Label : up
# Data 1437 : Original Label right, Prediction Label : right
# Data 1438 : Original Label on, Prediction Label : on
# Data 1439 : Original Label on, Prediction Label : off
# Data 1440 : Original Label stop, Prediction Label : stop
# Data 1441 : Original Label off, Prediction Label : off
# Data 1442 : Original Label up, Prediction Label : up
# Data 1443 : Original Label on, Prediction Label : on
# Data 1444 : Original Label on, Prediction Label : on
# Data 1445 : Original Label up, Prediction Label : up
# Data 1446 : Original Label up, Prediction Label : up
# Data 1447 : Original Label stop, Prediction Label : stop
# Data 1448 : Original Label down, Prediction Label : down
# Data 1449 : Original Label down, Prediction Label : down
# Data 1450 : Original Label up, Prediction Label : up
# Data 1451 : Original Label right, Prediction Label : right
# Data 1452 : Original Label left, Prediction Label : left
# Data 1453 : Original Label on, Prediction Label : on
# Data 1454 : Original Label down, Prediction Label : down
# Data 1455 : Original Label up, Prediction Label : off
# Data 1456 : Original Label down, Prediction Label : down
# Data 1457 : Original Label on, Prediction Label : on
# Data 1458 : Original Label on, Prediction Label : on
# Data 1459 : Original Label stop, Prediction Label : stop
# Data 1460 : Original Label down, Prediction Label : down
# Data 1461 : Original Label stop, Prediction Label : left
# Data 1462 : Original Label left, Prediction Label : left
# Data 1463 : Original Label stop, Prediction Label : stop
# Data 1464 : Original Label right, Prediction Label : right
# Data 1465 : Original Label up, Prediction Label : up
# Data 1466 : Original Label down, Prediction Label : down
# Data 1467 : Original Label up, Prediction Label : stop
# Data 1468 : Original Label on, Prediction Label : on
# Data 1469 : Original Label right, Prediction Label : right
# Data 1470 : Original Label off, Prediction Label : up
# Data 1471 : Original Label right, Prediction Label : right
# Data 1472 : Original Label on, Prediction Label : off
# Data 1473 : Original Label stop, Prediction Label : stop
# Data 1474 : Original Label left, Prediction Label : left
# Data 1475 : Original Label off, Prediction Label : off
# Data 1476 : Original Label right, Prediction Label : left
# Data 1477 : Original Label stop, Prediction Label : up
# Data 1478 : Original Label on, Prediction Label : on
# Data 1479 : Original Label stop, Prediction Label : stop
# Data 1480 : Original Label right, Prediction Label : right
# Data 1481 : Original Label on, Prediction Label : on
# Data 1482 : Original Label off, Prediction Label : off
# Data 1483 : Original Label off, Prediction Label : off
# Data 1484 : Original Label on, Prediction Label : on
# Data 1485 : Original Label on, Prediction Label : on
# Data 1486 : Original Label on, Prediction Label : on
# Data 1487 : Original Label off, Prediction Label : up
# Data 1488 : Original Label down, Prediction Label : down
# Data 1489 : Original Label up, Prediction Label : up
# Data 1490 : Original Label on, Prediction Label : on
# Data 1491 : Original Label left, Prediction Label : left
# Data 1492 : Original Label up, Prediction Label : up
# Data 1493 : Original Label off, Prediction Label : off
# Data 1494 : Original Label on, Prediction Label : up
# Data 1495 : Original Label left, Prediction Label : left
# Data 1496 : Original Label down, Prediction Label : down
# Data 1497 : Original Label up, Prediction Label : up
# Data 1498 : Original Label up, Prediction Label : up
# Data 1499 : Original Label left, Prediction Label : left
# Data 1500 : Original Label stop, Prediction Label : stop
# Data 1501 : Original Label stop, Prediction Label : stop
# Data 1502 : Original Label down, Prediction Label : down
# Data 1503 : Original Label stop, Prediction Label : stop
# Data 1504 : Original Label off, Prediction Label : off
# Data 1505 : Original Label stop, Prediction Label : stop
# Data 1506 : Original Label down, Prediction Label : down
# Data 1507 : Original Label off, Prediction Label : up
# Data 1508 : Original Label off, Prediction Label : off
# Data 1509 : Original Label on, Prediction Label : on
# Data 1510 : Original Label left, Prediction Label : left
# Data 1511 : Original Label down, Prediction Label : down
# Data 1512 : Original Label off, Prediction Label : off
# Data 1513 : Original Label stop, Prediction Label : stop
# Data 1514 : Original Label right, Prediction Label : right
# Data 1515 : Original Label stop, Prediction Label : stop
# Data 1516 : Original Label stop, Prediction Label : stop
# Data 1517 : Original Label down, Prediction Label : down
# Data 1518 : Original Label right, Prediction Label : right
# Data 1519 : Original Label off, Prediction Label : off
# Data 1520 : Original Label stop, Prediction Label : stop
# Data 1521 : Original Label stop, Prediction Label : stop
# Data 1522 : Original Label right, Prediction Label : right
# Data 1523 : Original Label stop, Prediction Label : stop
# Data 1524 : Original Label left, Prediction Label : left
# Data 1525 : Original Label on, Prediction Label : on
# Data 1526 : Original Label stop, Prediction Label : stop
# Data 1527 : Original Label off, Prediction Label : off
# Data 1528 : Original Label left, Prediction Label : left
# Data 1529 : Original Label left, Prediction Label : left
# Data 1530 : Original Label up, Prediction Label : up
# Data 1531 : Original Label left, Prediction Label : left
# Data 1532 : Original Label off, Prediction Label : off
# Data 1533 : Original Label on, Prediction Label : on
# Data 1534 : Original Label left, Prediction Label : left
# Data 1535 : Original Label down, Prediction Label : down
# Data 1536 : Original Label down, Prediction Label : down
# Data 1537 : Original Label left, Prediction Label : left
# Data 1538 : Original Label on, Prediction Label : on
# Data 1539 : Original Label right, Prediction Label : right
# Data 1540 : Original Label down, Prediction Label : down
# Data 1541 : Original Label left, Prediction Label : up
# Data 1542 : Original Label stop, Prediction Label : stop
# Data 1543 : Original Label on, Prediction Label : on
# Data 1544 : Original Label up, Prediction Label : up
# Data 1545 : Original Label down, Prediction Label : down
# Data 1546 : Original Label up, Prediction Label : up
# Data 1547 : Original Label up, Prediction Label : up
# Data 1548 : Original Label stop, Prediction Label : stop
# Data 1549 : Original Label stop, Prediction Label : stop
# Data 1550 : Original Label stop, Prediction Label : stop
# Data 1551 : Original Label down, Prediction Label : down
# Data 1552 : Original Label off, Prediction Label : left
# Data 1553 : Original Label stop, Prediction Label : stop
# Data 1554 : Original Label on, Prediction Label : on
# Data 1555 : Original Label up, Prediction Label : up
# Data 1556 : Original Label left, Prediction Label : left
# Data 1557 : Original Label left, Prediction Label : left
# Data 1558 : Original Label left, Prediction Label : left
# Data 1559 : Original Label up, Prediction Label : up
# Data 1560 : Original Label stop, Prediction Label : stop
# Data 1561 : Original Label off, Prediction Label : off
# Data 1562 : Original Label stop, Prediction Label : stop
# Data 1563 : Original Label off, Prediction Label : off
# Data 1564 : Original Label down, Prediction Label : down
# Data 1565 : Original Label down, Prediction Label : on
# Data 1566 : Original Label on, Prediction Label : on
# Data 1567 : Original Label off, Prediction Label : off
# Data 1568 : Original Label right, Prediction Label : right
# Data 1569 : Original Label stop, Prediction Label : stop
# Data 1570 : Original Label on, Prediction Label : on
# Data 1571 : Original Label up, Prediction Label : up
# Data 1572 : Original Label on, Prediction Label : on
# Data 1573 : Original Label right, Prediction Label : right
# Data 1574 : Original Label right, Prediction Label : right
# Data 1575 : Original Label up, Prediction Label : up
# Data 1576 : Original Label off, Prediction Label : off
# Data 1577 : Original Label stop, Prediction Label : stop
# Data 1578 : Original Label left, Prediction Label : left
# Data 1579 : Original Label up, Prediction Label : up
# Data 1580 : Original Label left, Prediction Label : left
# Data 1581 : Original Label up, Prediction Label : up
# Data 1582 : Original Label down, Prediction Label : down
# Data 1583 : Original Label right, Prediction Label : right
# Data 1584 : Original Label up, Prediction Label : up
# Data 1585 : Original Label down, Prediction Label : down
# Data 1586 : Original Label off, Prediction Label : off
# Data 1587 : Original Label down, Prediction Label : down
# Data 1588 : Original Label off, Prediction Label : off
# Data 1589 : Original Label down, Prediction Label : down
# Data 1590 : Original Label down, Prediction Label : down
# Data 1591 : Original Label on, Prediction Label : off
# Data 1592 : Original Label right, Prediction Label : right
# Data 1593 : Original Label down, Prediction Label : down
# Data 1594 : Original Label off, Prediction Label : off
# Data 1595 : Original Label off, Prediction Label : off
# Data 1596 : Original Label right, Prediction Label : right
# Data 1597 : Original Label off, Prediction Label : off
# Data 1598 : Original Label up, Prediction Label : up
# Data 1599 : Original Label down, Prediction Label : down
# Data 1600 : Original Label up, Prediction Label : up
# Data 1601 : Original Label right, Prediction Label : right
# Data 1602 : Original Label stop, Prediction Label : stop
# Data 1603 : Original Label up, Prediction Label : up
# Data 1604 : Original Label left, Prediction Label : left
# Data 1605 : Original Label off, Prediction Label : off
# Data 1606 : Original Label on, Prediction Label : on
# Data 1607 : Original Label up, Prediction Label : up
# Data 1608 : Original Label off, Prediction Label : off
# Data 1609 : Original Label left, Prediction Label : left
# Data 1610 : Original Label up, Prediction Label : up
# Data 1611 : Original Label right, Prediction Label : right
# Data 1612 : Original Label on, Prediction Label : on
# Data 1613 : Original Label off, Prediction Label : off
# Data 1614 : Original Label left, Prediction Label : left
# Data 1615 : Original Label stop, Prediction Label : stop
# Data 1616 : Original Label stop, Prediction Label : stop
# Data 1617 : Original Label left, Prediction Label : left
# Data 1618 : Original Label stop, Prediction Label : stop
# Data 1619 : Original Label right, Prediction Label : right
# Data 1620 : Original Label right, Prediction Label : right
# Data 1621 : Original Label down, Prediction Label : down
# Data 1622 : Original Label up, Prediction Label : up
# Data 1623 : Original Label down, Prediction Label : down
# Data 1624 : Original Label up, Prediction Label : up
# Data 1625 : Original Label left, Prediction Label : left
# Data 1626 : Original Label on, Prediction Label : up
# Data 1627 : Original Label on, Prediction Label : on
# Data 1628 : Original Label off, Prediction Label : off
# Data 1629 : Original Label up, Prediction Label : up
# Data 1630 : Original Label right, Prediction Label : right
# Data 1631 : Original Label on, Prediction Label : on
# Data 1632 : Original Label up, Prediction Label : up
# Data 1633 : Original Label left, Prediction Label : left
# Data 1634 : Original Label left, Prediction Label : left
# Data 1635 : Original Label right, Prediction Label : right
# Data 1636 : Original Label up, Prediction Label : up
# Data 1637 : Original Label right, Prediction Label : right
# Data 1638 : Original Label on, Prediction Label : on
# Data 1639 : Original Label left, Prediction Label : left
# Data 1640 : Original Label up, Prediction Label : up
# Data 1641 : Original Label on, Prediction Label : on
# Data 1642 : Original Label off, Prediction Label : off
# Data 1643 : Original Label off, Prediction Label : off
# Data 1644 : Original Label up, Prediction Label : up
# Data 1645 : Original Label on, Prediction Label : on
# Data 1646 : Original Label stop, Prediction Label : stop
# Data 1647 : Original Label left, Prediction Label : left
# Data 1648 : Original Label stop, Prediction Label : stop
# Data 1649 : Original Label up, Prediction Label : stop
# Data 1650 : Original Label right, Prediction Label : right
# Data 1651 : Original Label on, Prediction Label : on
# Data 1652 : Original Label up, Prediction Label : up
# Data 1653 : Original Label stop, Prediction Label : stop
# Data 1654 : Original Label up, Prediction Label : up
# Data 1655 : Original Label up, Prediction Label : up
# Data 1656 : Original Label stop, Prediction Label : stop
# Data 1657 : Original Label stop, Prediction Label : up
# Data 1658 : Original Label left, Prediction Label : left
# Data 1659 : Original Label off, Prediction Label : off
# Data 1660 : Original Label right, Prediction Label : right
# Data 1661 : Original Label right, Prediction Label : right
# Data 1662 : Original Label right, Prediction Label : right
# Data 1663 : Original Label on, Prediction Label : on

# %%
prediction = np.array(prediction)
true_prediction= np.array(true_prediction)

test_accuracy = np.mean(prediction == true_prediction)

print(f"Accuracy from the validation : {np.max(VALIDATION_ACCURACY)}")
print(f"Accuracy of the test : {test_accuracy}")
# Out:
# Accuracy from the validation : 0.9312438368797302
# Accuracy of the test : 0.9092548076923077
